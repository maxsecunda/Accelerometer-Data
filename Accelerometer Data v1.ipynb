# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import axes3d

# %%
cols = ["index", "id", "x", "y", "z", "file"]
file = pd.read_csv(r"C:\Users\maxse\OneDrive\Documents\Python Ac Project\Test1.tsv", sep="\t", names=cols)
print(file.head())
# Out:
#    index             id      x      y      z   file
# 0      1  1604661749176 -0.098  8.141  5.959  Test1
# 1      2  1604661749371 -0.266  8.263  5.603  Test1
# 2      3  1604661749372 -0.211  8.117  5.366  Test1
# 3      4  1604661749373 -0.048  8.023  5.121  Test1
# 4      5  1604661749374 -0.136  7.968  4.793  Test1

# %%
coordinates = file[["x", "y", "z"]]
print(coordinates.head())
# Out:
#        x      y      z
# 0 -0.098  8.141  5.959
# 1 -0.266  8.263  5.603
# 2 -0.211  8.117  5.366
# 3 -0.048  8.023  5.121
# 4 -0.136  7.968  4.793

# %%
top_500 = coordinates.head(500)

# %%
fig = plt.figure()
ax =  plt.axes(projection="3d")
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
x = top_500[["x"]]
y = top_500[["y"]]
z = top_500[["z"]]

ax.scatter(x,y,z)
plt.show()

# %%
fig = plt.figure()
ax_2 = plt.axes(projection="3d")
ax_2.plot_wireframe(x,y,z)
plt.show()
